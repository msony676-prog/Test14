# %% [raw]
# Q1.What are the evaluation metrics of regression and classification?
# Regression metrics
# 1.Mean squared erroe:Measures average aquared difference between actual and predicted values.
# 2.Root Mean squared error : esier to interpret because same units as target varible
# 3.Mean absolute error:Average absolute diffrence between actual and predicted values.
# 4.R square score : Measure how well the model explains the variance in the data.
# Classification Metrics
# 1.Accuracy
# 2.Precision
# 3.Confusion Matrix:table showing TP,TN,FP,FN

# %% [raw]
# Q2. What is Naïve Bayes classifier? Build model  using any seaborn dataset.
# Naive Bayes Classifier
# Based on Bayes Theorem
# P(A/B)=P(B/A)P(A)
#        ----------
#           P(B)
# Naive = assumes all features are independent

# %%
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\admin\Downloads\german_credit.csv")

# %%
df.head(3)
# Out:
#    Creditability  Account Balance  Duration of Credit (month)  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# 1                     1                             3                    2
# 2                     2                             4                    2
#
#    Sex & Marital Status  ...  Duration in Current address  \
# 0                     2  ...                            4
# ...

# %%
X = df.drop('Creditability',axis=1)
y = df['Creditability']

# %%
X
# Out:
#      Account Balance  Duration of Credit (month)  \
# 0                  1                          18
# 1                  1                           9
# 2                  2                          12
# 3                  1                          12
# 4                  1                          12
# ..               ...                         ...
# 995                1                          24
# 996                1                          24
# 997                4                          21
# 998                2                          12
# 999                1                          30
#
#      Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                    4        2           1049
# 1                                    4        0           2799
# 2                                    2        9            841
# 3                                    4        0           2122
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Creditability, Length: 1000, dtype: int64

# %%
df.isnull().sum()
# Out:
# Creditability                        0
# Account Balance                      0
# Duration of Credit (month)           0
# Payment Status of Previous Credit    0
# Purpose                              0
# Credit Amount                        0
# Value Savings/Stocks                 0
# Length of current employment         0
# Instalment per cent                  0
# Sex & Marital Status                 0
# Guarantors                           0
# Duration in Current address          0
# Most valuable available asset        0
# Age (years)                          0
# Concurrent Credits                   0
# Type of apartment                    0
# No of Credits at this Bank           0
# Occupation                           0
# No of dependents                     0
# Telephone                            0
# Foreign Worker                       0
# dtype: int64

# %%
 df.columns
set(y)
# Out:
# {0, 1}

# %%
for label in set(y):
    plt.scatter(X.loc[y == label,'Duration of Credit (month)'],X.loc[y == label,'Credit Amount'],label = label)
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
import matplotlib.pyplot as plt
from collections import Counter

# %%
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X, y)

# %%
print("Class distribution after under-sampling:", Counter(y_res))
# Out:
# Class distribution after under-sampling: Counter({0: 300, 1: 300})

# %%
sns.countplot(x=y_res)
plt.title("Class Distribution After Under-Sampling")
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.2,stratify = y,random_state = 42)

# %%
print("Train size:", X_train.shape)
print("Test size:", X_test.shape)
# Out:
# Train size: (800, 20)
# Test size: (200, 20)

# %% [raw]
# Q3. What are feature transformers?
#  Feature transformers are  techniques that transform raw data into a
# format that machine learning models can use effectively.
# 1.Scalling :make numeric features comparable
# 2.Encoding : convert text into numbers
# 3.log/cox transformers: transform skewed features to make distribution closer to normal

# %%
Q4.What is SMOTE? Draw diagram and explain.
SMOTE Synthetic Minority Oversampling Technique.
Distance between random data and its K-nearest neighbors.
Instead of duplicating existing points, it generates new points along the line
between existing minority points, improving the classifier’s ability to learn.
d1[numerical]*[0-1]
   minority class     SMOTE
    o o                o o o
     o                  o

# %%
Q5.How to avoid overfitting in regression model?
always split data into taining and testing sets
